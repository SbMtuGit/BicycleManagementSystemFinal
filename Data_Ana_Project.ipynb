# %% [markdown]
# <a href="https://colab.research.google.com/github/SbMtuGit/BicycleManagementSystemFinal/blob/master/Data_Ana_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Heading Descriptors**
# **Spotify headings defs**
#
# *What makes music danceable what audio elements make a track danceable**
#
# **danceability**
# number [float]
# Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **valence**
# number [float]
# A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry)
#
# **tempo**
# number [float]
# The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# **Energy**
# energy
# number [float]
# Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# Example: 0.842
#
#
# *** what are Realtionship between these attributes*

# %%
## imports needed for data analysis on csv file
## matplotlib for plotting graphs
## seaborn for styling graphs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# **First cell **
#
# This cell includes all the needed imports for analysing the csv data file.
# Numpy is used for any numerical operations
# Pandas is used for data anyaltics that are needed
# matplotlab is used for plotting graphs
# seaborn is used for styling the plotted graphs
#
# NB READ https://dhruv-khurjekar.medium.com/investigating-spotifys-danceability-index-other-song-attributes-1983142f7dfd
#
# NB SPOTIFY FOR DEVS https://developer.spotify.com/documentation/web-api/reference/get-audio-features

# %%
## csv file read intp a data frame with pandas
df=pd.read_csv('/content/universal_top_spotify_songs.csv')

# %% [markdown]
# **Second cell**
#
# This cell creates a Dataframe using pandas so that the csv file can read and saved within the DataFrame

# %%
## print the head of the csv file
pd.set_option('display.max_columns', None)
df.head(len(df))
# Out:
#                      spotify_id                               name  \
# 0        2plbrEY59IikOBgBGLjaoe                   Die With A Smile
# 1        5vNRhkKd0yEAg8suGBpjeY                               APT.
# 2        6dOtVTDdiauQNBQEDOtlAB                 BIRDS OF A FEATHER
# 3        7ne4VBA60CxGM75vw0EYad                     That’s So True
# 4        1cOboCuWYI2osTOfolMRS6                            Tu Boda
# ...                         ...                                ...
# 1407882  0AYt6NMyyLd0rLuvr0UkMH          Slime You Out (feat. SZA)
# 1407883  2Gk6fi0dqt91NKvlzGsmm7  SAY MY GRACE (feat. Travis Scott)
# 1407884  26b3oVLrRUaaybJulow9kz                             People
# 1407885  5ydjxBSUIDn26MFzU3asP4                         Rainy Days
# 1407886  59NraMJsLaMCVtwXTSia8i                              Prada
#
#                              artists  daily_rank  daily_movement  \
# 0              Lady Gaga, Bruno Mars           1               0
# ...

# %% [markdown]
# **Third Cell**
# This cell deals with printing the dataframe

# %%
## missing values in each column and the amount
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# spotify_id                0
# name                     29
# artists                  28
# daily_rank                0
# daily_movement            0
# weekly_movement           0
# country               19157
# snapshot_date             0
# popularity                0
# is_explicit               0
# duration_ms               0
# album_name              670
# album_release_date      507
# danceability              0
# energy                    0
# key                       0
# loudness                  0
# mode                      0
# speechiness               0
# acousticness              0
# instrumentalness          0
# liveness                  0
# valence                   0
# tempo                     0
# time_signature            0
# dtype: int64

# %%
df['release_decade'] = pd.to_datetime(df['album_release_date']).dt.year // 10 * 10

# %%
df_ranked = df.sort_values(['release_decade', 'popularity'], ascending=[True, False]) \
              .groupby('release_decade') \
              .head(10)

# %%
# Out:
#                                     spotify_id  \
# release_decade
# 1950.0         1155261  2uFaJJtFpPDc5Pa95XzTvg
#                1177572  2uFaJJtFpPDc5Pa95XzTvg
#                1158107  2uFaJJtFpPDc5Pa95XzTvg
#                1158058  2uFaJJtFpPDc5Pa95XzTvg
#                1176813  2uFaJJtFpPDc5Pa95XzTvg
#                1157768  2uFaJJtFpPDc5Pa95XzTvg
#                1176917  2uFaJJtFpPDc5Pa95XzTvg
#                1157727  2uFaJJtFpPDc5Pa95XzTvg
#                1177163  2uFaJJtFpPDc5Pa95XzTvg
#                1157666  2uFaJJtFpPDc5Pa95XzTvg
#
#                                                           name      artists  \
# release_decade
# 1950.0         1155261  Let It Snow! Let It Snow! Let It Snow!  Dean Martin
#                1177572  Let It Snow! Let It Snow! Let It Snow!  Dean Martin
#                1158107  Let It Snow! Let It Snow! Let It Snow!  Dean Martin
#                1158058  Let It Snow! Let It Snow! Let It Snow!  Dean Martin
# ...

# %%
# Out:
#   File "<ipython-input-20-c404e9c74be0>", line 2
#     decade_1950s = df_ranked[df_ranked['release_decade'] == 1950]
#     ^
# IndentationError: unexpected indent
